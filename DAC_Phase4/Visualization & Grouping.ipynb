# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading the dataset 
df=pd.read_csv("preprocessed_data.csv")

# %%
df.head(-1)
# Out:
#     Table Code State Code District Code            Area Name  \
# 0      B0806SC        `33          `000   State - TAMIL NADU
# 1      B0806SC        `33          `000   State - TAMIL NADU
# 2      B0806SC        `33          `000   State - TAMIL NADU
# 3      B0806SC        `33          `000   State - TAMIL NADU
# 4      B0806SC        `33          `000   State - TAMIL NADU
# ..         ...        ...           ...                  ...
# 588    B0806SC        `33          `633  District - Tiruppur
# 589    B0806SC        `33          `633  District - Tiruppur
# 590    B0806SC        `33          `633  District - Tiruppur
# 591    B0806SC        `33          `633  District - Tiruppur
# 592    B0806SC        `33          `633  District - Tiruppur
#
#     Total/ Rural/ Urban Age Group  \
# 0                 Total     Total
# 1                 Total     `5-14
# 2                 Total     15-34
# 3                 Total     35-59
# 4                 Total       60+
# ...

# %%
olumns=['Worked for 3 months or more but less than 6 months -  Persons',
'Worked for less than 3 months - Persons',
'Industrial Category - A - Cultivators - Persons',	
'Industrial Category - A - Agricultural labourers - Persons',	
'Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons',
'Industrial Category - B - Persons',
'Industrial Category - C - HHI - Persons',	
'Industrial Category - C - Non HHI - Persons',	
'Industrial Category - D & E - Persons',	
'Industrial Category - F - Persons',	
'Industrial Category - G - HHI - Persons',	
'Industrial Category - G - Non HHI - Persons',
'Industrial Category - H - Persons',	
'Industrial Category - I - Persons',	
]

# %%
#Grouping of workers based on area name
a=df.groupby(["District Code","Area Name"])[columns].agg("sum")
pd.set_option('display.max_columns', None)
a
# Out:
#                                           Worked for 3 months or more but less than 6 months -  Persons  \
# District Code Area Name
# `000          State - TAMIL NADU                                                    4803312
# `602          District - Thiruvallur                                                 297792
# `603          District - Chennai                                                     134992
# `604          District - Kancheepuram                                                368060
# `605          District - Vellore                                                     286780
# `606          District - Tiruvannamalai                                              261904
# `607          District - Viluppuram                                                  548108
# `608          District - Salem                                                       101664
# `609          District - Namakkal                                                     62668
# ...

# %%
#Plotting based on Area Name-Part 1
grouped = a.reset_index()
fig,axes=plt.subplots(2,4,figsize=(28,15))
axes[0,0].bar(grouped['Area Name'],grouped['Industrial Category - A - Cultivators - Persons'],width=0.5)
axes[0,1].bar(grouped['Area Name'],grouped['Industrial Category - A - Agricultural labourers - Persons'],width=0.5)
axes[0,2].bar(grouped['Area Name'],grouped['Industrial Category - B - Persons'],width=0.5)
axes[0,3].bar(grouped['Area Name'],grouped['Industrial Category - C - HHI - Persons'],width=0.5)
axes[1,0].bar(grouped['Area Name'],grouped['Industrial Category - C - Non HHI - Persons'],width=0.5)
axes[1,1].bar(grouped['Area Name'],grouped['Industrial Category - D & E - Persons'],width=0.5)
axes[1,2].bar(grouped['Area Name'],grouped['Industrial Category - F - Persons'],width=0.5)
axes[1,3].bar(grouped['Area Name'],grouped['Industrial Category - G - HHI - Persons'],width=0.5)
axes[0,0].set_title("Industrial Category - A - Cultivators - Persons")
axes[0,1].set_title("Industrial Category - A - Agricultural labourers - Persons")
axes[0,2].set_title("Industrial Category - B - Persons")
axes[0,3].set_title("Industrial Category - C - HHI - Persons")
axes[1,0].set_title("Industrial Category - C - Non HHI - Persons")
axes[1,1].set_title("Industrial Category - D & E - Persons")
axes[1,2].set_title("Industrial Category - F - Persons")
axes[1,3].set_title("Industrial Category - G - HHI - Persons")
axes[0,0].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[0,1].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[0,2].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[0,3].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[1,0].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[1,1].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[1,2].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[1,3].set_xticklabels(grouped['Area Name'], rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\3139045490.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0,0].set_xticklabels(grouped['Area Name'], rotation=90)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\3139045490.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0,1].set_xticklabels(grouped['Area Name'], rotation=90)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\3139045490.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0,2].set_xticklabels(grouped['Area Name'], rotation=90)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\3139045490.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0,3].set_xticklabels(grouped['Area Name'], rotation=90)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\3139045490.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
#Plotting based on Area Name-Part 2
grouped = a.reset_index()
fig,axes=plt.subplots(2,3,figsize=(28,15))
axes[0,0].bar(grouped['Area Name'],grouped['Worked for 3 months or more but less than 6 months -  Persons'],width=0.5)
axes[0,1].bar(grouped['Area Name'],grouped['Worked for less than 3 months - Persons'],width=0.5)
axes[0,2].bar(grouped['Area Name'],
grouped['Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons'],
width=0.5)
axes[1,0].bar(grouped['Area Name'],grouped['Industrial Category - G - Non HHI - Persons'],width=0.5)
axes[1,1].bar(grouped['Area Name'],grouped['Industrial Category - H - Persons'],width=0.5)
axes[1,2].bar(grouped['Area Name'],grouped['Industrial Category - I - Persons'],width=0.5)
axes[0,0].set_title("Worked for 3 months or more but less than 6 months -  Persons")
axes[0,1].set_title("Worked for less than 3 months - Persons")
axes[0,2].set_title("Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons")
axes[1,0].set_title("Industrial Category - G - Non HHI - Persons")
axes[1,1].set_title("Industrial Category - H - Persons")
axes[1,2].set_title("Industrial Category - I - Persons")
axes[0,0].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[0,1].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[0,2].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[1,0].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[1,1].set_xticklabels(grouped['Area Name'], rotation=90) 
axes[1,2].set_xticklabels(grouped['Area Name'], rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\944423085.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0,0].set_xticklabels(grouped['Area Name'], rotation=90)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\944423085.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0,1].set_xticklabels(grouped['Area Name'], rotation=90)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\944423085.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0,2].set_xticklabels(grouped['Area Name'], rotation=90)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\944423085.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1,0].set_xticklabels(grouped['Area Name'], rotation=90)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14300\944423085.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
#Plotting based on Total/ Rural/ Urban-Part 1
grouped = a.reset_index()
fig,axes=plt.subplots(2,4,figsize=(28,10))
axes[0,0].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - A - Cultivators - Persons'],width=0.3)
axes[0,1].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - A - Agricultural labourers - Persons'],width=0.3)
axes[0,2].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - B - Persons'],width=0.3)
axes[0,3].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - C - HHI - Persons'],width=0.3)
axes[1,0].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - C - Non HHI - Persons'],width=0.3)
axes[1,1].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - D & E - Persons'],width=0.3)
axes[1,2].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - F - Persons'],width=0.3)
axes[1,3].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - G - HHI - Persons'],width=0.3)
axes[0,0].set_title("Industrial Category - A - Cultivators - Persons")
axes[0,1].set_title("Industrial Category - A - Agricultural labourers - Persons")
axes[0,2].set_title("Industrial Category - B - Persons")
axes[0,3].set_title("Industrial Category - C - HHI - Persons")
axes[1,0].set_title("Industrial Category - C - Non HHI - Persons")
axes[1,1].set_title("Industrial Category - D & E - Persons")
axes[1,2].set_title("Industrial Category - F - Persons")
axes[1,3].set_title("Industrial Category - G - HHI - Persons")
plt.tight_layout()
plt.show()

# %%
#Grouping based on Age Group
a=df.groupby("Age Group")[columns].agg("sum")
pd.set_option('display.max_columns', None)
a
# Out:
#                 Worked for 3 months or more but less than 6 months -  Persons  \
# Age Group
# 15-34                                                     2057360
# 35-59                                                     2170324
# 60+                                                        460412
# Age not stated                                               4052
# Total                                                     4803312
# `5-14                                                      111164
#
#                 Worked for less than 3 months - Persons  \
# Age Group
# 15-34                                            369692
# 35-59                                            396808
# 60+                                              108660
# Age not stated                                      596
# Total                                            885544
# `5-14                                              9788
#
#                 Industrial Category - A - Cultivators - Persons  \
# ...

# %%
#Plotting based on Age Group-Part 1
grouped = a.reset_index()
fig,axes=plt.subplots(2,4,figsize=(28,15))
axes[0,0].bar(grouped['Age Group'],grouped['Industrial Category - A - Cultivators - Persons'],width=0.3)
axes[0,1].bar(grouped['Age Group'],grouped['Industrial Category - A - Agricultural labourers - Persons'],width=0.3)
axes[0,2].bar(grouped['Age Group'],grouped['Industrial Category - B - Persons'],width=0.3)
axes[0,3].bar(grouped['Age Group'],grouped['Industrial Category - C - HHI - Persons'],width=0.3)
axes[1,0].bar(grouped['Age Group'],grouped['Industrial Category - C - Non HHI - Persons'],width=0.3)
axes[1,1].bar(grouped['Age Group'],grouped['Industrial Category - D & E - Persons'],width=0.3)
axes[1,2].bar(grouped['Age Group'],grouped['Industrial Category - F - Persons'],width=0.3)
axes[1,3].bar(grouped['Age Group'],grouped['Industrial Category - G - HHI - Persons'],width=0.3)
axes[0,0].set_title("Industrial Category - A - Cultivators - Persons")
axes[0,1].set_title("Industrial Category - A - Agricultural labourers - Persons")
axes[0,2].set_title("Industrial Category - B - Persons")
axes[0,3].set_title("Industrial Category - C - HHI - Persons")
axes[1,0].set_title("Industrial Category - C - Non HHI - Persons")
axes[1,1].set_title("Industrial Category - D & E - Persons")
axes[1,2].set_title("Industrial Category - F - Persons")
axes[1,3].set_title("Industrial Category - G - HHI - Persons")
plt.tight_layout()
plt.show()

# %%
#Plotting based on Age Group-Part 2
grouped = a.reset_index()
fig,axes=plt.subplots(2,3,figsize=(28,15))
axes[0,0].bar(grouped['Age Group'],grouped['Worked for 3 months or more but less than 6 months -  Persons'],width=0.3)
axes[0,1].bar(grouped['Age Group'],grouped['Worked for less than 3 months - Persons'],width=0.3)
axes[0,2].bar(grouped['Age Group'],
grouped['Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons'],width=0.3)
axes[1,0].bar(grouped['Age Group'],grouped['Industrial Category - G - Non HHI - Persons'],width=0.3)
axes[1,1].bar(grouped['Age Group'],grouped['Industrial Category - H - Persons'],width=0.3)
axes[1,2].bar(grouped['Age Group'],grouped['Industrial Category - I - Persons'],width=0.3)
axes[0,0].set_title("Worked for 3 months or more but less than 6 months -  Persons")
axes[0,1].set_title("Worked for less than 3 months - Persons")
axes[0,2].set_title("Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons")
axes[1,0].set_title("Industrial Category - G - Non HHI - Persons")
axes[1,1].set_title("Industrial Category - H - Persons")
axes[1,2].set_title("Industrial Category - I - Persons")
plt.tight_layout()
plt.show()

# %%
#Grouping based on Total/Rural/Urban
a=df.groupby("Total/ Rural/ Urban")[columns].agg("sum")
pd.set_option('display.max_columns', None)
a
# Out:
#                      Worked for 3 months or more but less than 6 months -  Persons  \
# Total/ Rural/ Urban
# Rural                                                          3866580
# Total                                                          4803312
# Urban                                                           936732
#
#                      Worked for less than 3 months - Persons  \
# Total/ Rural/ Urban
# Rural                                                 697772
# Total                                                 885544
# Urban                                                 187772
#
#                      Industrial Category - A - Cultivators - Persons  \
# Total/ Rural/ Urban
# Rural                                                         238548
# Total                                                         256940
# Urban                                                          18392
#
# ...

# %%
#Plotting based on Total/ Rural/ Urban-Part 1
grouped = a.reset_index()
fig,axes=plt.subplots(2,4,figsize=(28,10))
axes[0,0].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - A - Cultivators - Persons'],width=0.3)
axes[0,1].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - A - Agricultural labourers - Persons'],width=0.3)
axes[0,2].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - B - Persons'],width=0.3)
axes[0,3].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - C - HHI - Persons'],width=0.3)
axes[1,0].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - C - Non HHI - Persons'],width=0.3)
axes[1,1].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - D & E - Persons'],width=0.3)
axes[1,2].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - F - Persons'],width=0.3)
axes[1,3].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - G - HHI - Persons'],width=0.3)
axes[0,0].set_title("Industrial Category - A - Cultivators - Persons")
axes[0,1].set_title("Industrial Category - A - Agricultural labourers - Persons")
axes[0,2].set_title("Industrial Category - B - Persons")
axes[0,3].set_title("Industrial Category - C - HHI - Persons")
axes[1,0].set_title("Industrial Category - C - Non HHI - Persons")
axes[1,1].set_title("Industrial Category - D & E - Persons")
axes[1,2].set_title("Industrial Category - F - Persons")
axes[1,3].set_title("Industrial Category - G - HHI - Persons")
plt.tight_layout()
plt.show()

# %%
#Plotting based on Total/ Rural/ Urban-Part 2
grouped = a.reset_index()
fig,axes=plt.subplots(2,3,figsize=(28,15))
axes[0,0].bar(grouped['Total/ Rural/ Urban'],grouped['Worked for 3 months or more but less than 6 months -  Persons'],width=0.3)
axes[0,1].bar(grouped['Total/ Rural/ Urban'],grouped['Worked for less than 3 months - Persons'],width=0.3)
axes[0,2].bar(grouped['Total/ Rural/ Urban'],
grouped['Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons'],width=0.3)
axes[1,0].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - G - Non HHI - Persons'],width=0.3)
axes[1,1].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - H - Persons'],width=0.3)
axes[1,2].bar(grouped['Total/ Rural/ Urban'],grouped['Industrial Category - I - Persons'],width=0.3)
axes[0,0].set_title("Worked for 3 months or more but less than 6 months -  Persons")
axes[0,1].set_title("Worked for less than 3 months - Persons")
axes[0,2].set_title("Industrial Category - A - Plantation, Livestock, Forestry, Fishing, Hunting and allied activities - Persons")
axes[1,0].set_title("Industrial Category - G - Non HHI - Persons")
axes[1,1].set_title("Industrial Category - H - Persons")
axes[1,2].set_title("Industrial Category - I - Persons")
plt.tight_layout()
plt.show()
